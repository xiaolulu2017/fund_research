# %%
import tushare as ts
pro = ts.pro_api(token='c0bda41e765e44ea2c2145b65063e89fec15dec167604c96085ad795')

# %%
funds = pro.fund_basic(market='O', status='L')

# %%
funds.shape[0]
# Out:
# 14995

# %%
funds300=funds[funds['name'].str.contains('300')].copy()

# %%
funds300
# Out:
#          ts_code            name management custodian fund_type found_date  \
# 66     016134.OF      嘉实沪深300增强C       嘉实基金    中国建设银行       股票型   20220708
# 607    015671.OF      前海开源沪深300C     前海开源基金    中国农业银行       股票型   20220429
# 609    015679.OF    景顺长城沪深300增强C     景顺长城基金    中国农业银行       股票型   20220429
# 835    015387.OF    中欧沪深300指数增强A       中欧基金      国泰君安       股票型   20220329
# 836    015388.OF    中欧沪深300指数增强C       中欧基金      国泰君安       股票型   20220329
# ...          ...             ...        ...       ...       ...        ...
# 14707  020011.OF        国泰沪深300A       国泰基金      中国银行       股票型   20071111
# 14835  519300.OF        大成沪深300A       大成基金    中国农业银行       股票型   20060406
# 14899  310318.OF  申万菱信沪深300指数增强A     申万菱信基金    中国工商银行       股票型   20041129
# 14922  200002.OF      长城久泰沪深300A       长城基金      招商银行       股票型   20040521
# 14956  050002.OF      博时裕富沪深300A       博时基金    中国建设银行       股票型   20030826
#
# ...

# %%
for code in funds300['ts_code']:
    print(code)
    nav = pro.fund_nav(ts_code=code)
    nav.to_pickle('data\%s.pkl'%code, compression='zip')
# Out:
# 016134.OF
# 015671.OF
# 015679.OF
# 015387.OF
# 015388.OF
# 015279.OF
# 015278.OF
# 012664.OF
# 012663.OF
# 014372.OF
# 012713.OF
# 012712.OF
# 013120.OF
# 013291.OF
# 013273.OF
# 013074.OF
# 012912.OF
# 012911.OF
# 012207.OF
# 012206.OF
# 011546.OF
# 011545.OF
# 011499.OF
# 011498.OF
# 011132.OF
# 011133.OF
# 011316.OF
# 011317.OF
# 010908.OF
# 010909.OF
# 010855.OF
# 010854.OF
# 010872.OF
# 010873.OF
# 010737.OF
# 010736.OF
# 010556.OF
# 005530.OF
# 010432.OF
# 010352.OF
# 008777.OF
# 008776.OF
# 008927.OF
# 008926.OF
# 009208.OF
# 165310.OF
# 009060.OF
# 009059.OF
# 008238.OF
# 008239.OF
# 008973.OF
# 008593.OF
# 008592.OF
# 008291.OF
# 008292.OF
# 008391.OF
# 008390.OF
# 008184.OF
# 005248.OF
# 007605.OF
# 007606.OF
# 007275.OF
# 007276.OF
# 005103.OF
# 005102.OF
# 007882.OF
# 007883.OF
# 007800.OF
# 007804.OF
# 007538.OF
# 007539.OF
# 007144.OF
# 007143.OF
# 007230.OF
# 007404.OF
# 007448.OF
# 007044.OF
# 007045.OF
# 007339.OF
# 007096.OF
# 006600.OF
# 007039.OF
# 006937.OF
# ...

# %%
nav = pro.fund_nav(ts_code='005002.OF')
nav
# Out:
#        ts_code  ann_date  nav_date  unit_nav accum_nav accum_div   net_asset  \
# 0    005002.OF  20190809  20190808       1.0      None      None  9783680.32
# 1    005002.OF  20190808  20190807       1.0      None      None         NaN
# 2    005002.OF  20190807  20190806       1.0      None      None         NaN
# 3    005002.OF  20190806  20190805       1.0      None      None         NaN
# 4    005002.OF  20190806  20190804       1.0      None      None         NaN
# ..         ...       ...       ...       ...       ...       ...         ...
# 466  005002.OF  20180112  20180111       1.0      None      None    18612.94
# 467  005002.OF  20180106  20180105       1.0      None      None    18605.62
# 468  005002.OF  20180101  20171231       1.0      None      None    18592.20
# 469  005002.OF  20171230  20171229       1.0      None      None    18573.23
# 470  005002.OF      None  20171228       1.0      None      None         NaN
#
#      total_netasset     adj_nav update_flag
# ...

# %%
funds500=funds[funds['name'].str.contains('500')].copy()
funds500
# Out:
#          ts_code                name management custodian fund_type  \
# 21     159620.OF  华夏中证智选500成长创新策略ETF       华夏基金    中国建设银行       股票型
# 317    015508.OF        兴业中证500指数增强C       兴业基金      海通证券       股票型
# 318    015507.OF        兴业中证500指数增强A       兴业基金      海通证券       股票型
# 440    014587.OF        华安中证500指数增强A       华安基金      招商银行       股票型
# 446    014588.OF        华安中证500指数增强C       华安基金      招商银行       股票型
# ...          ...                 ...        ...       ...       ...
# 13963  000008.OF       嘉实中证500ETF联接A       嘉实基金    中国建设银行       股票型
# 14144  050025.OF       博时标普500ETF联接A       博时基金    中国工商银行       股票型
# 14156  519034.OF         海富通中证500增强A      海富通基金    中国建设银行       股票型
# 14227  660011.OF           农银汇理中证500     农银汇理基金      交通银行       股票型
# 14332  096001.OF       大成标普500等权重人民币       大成基金      中国银行       股票型
#
#       found_date due_date list_date issue_date delist_date  ...  min_amount  \
# ...

# %%
for code in funds500['ts_code']:
    print(code)
    nav = pro.fund_nav(ts_code=code)
    nav.to_pickle('data\%s.pkl'%code, compression='zip')
# Out:
# 159620.OF
# 015508.OF
# 015507.OF
# 014587.OF
# 014588.OF
# 015454.OF
# 015453.OF
# 014305.OF
# 014306.OF
# 014018.OF
# 014019.OF
# 014345.OF
# 014344.OF
# 014155.OF
# 014156.OF
# 014133.OF
# 014134.OF
# 013879.OF
# 013878.OF
# 013881.OF
# 013833.OF
# 013834.OF
# 013640.OF
# 013639.OF
# 012498.OF
# 012499.OF
# 013404.OF
# 013425.OF
# 013499.OF
# 013119.OF
# 013332.OF
# 013233.OF
# 013234.OF
# 012927.OF
# 012926.OF
# 012861.OF
# 012860.OF
# 012275.OF
# 012276.OF
# 012081.OF
# 012080.OF
# 010253.OF
# 011205.OF
# 010992.OF
# 010993.OF
# 009726.OF
# 009727.OF
# 010066.OF
# 010067.OF
# 010157.OF
# 010158.OF
# 010355.OF
# 009608.OF
# 009609.OF
# 010154.OF
# 010153.OF
# 009613.OF
# 009614.OF
# 009337.OF
# 009336.OF
# 008259.OF
# 008258.OF
# 006440.OF
# 006441.OF
# 009300.OF
# 007994.OF
# 007995.OF
# 009004.OF
# 164809.OF
# 007223.OF
# 008778.OF
# 008779.OF
# 008001.OF
# 007932.OF
# 007885.OF
# 007886.OF
# 008396.OF
# 008397.OF
# 590007.OF
# 008124.OF
# 008113.OF
# 008112.OF
# 007943.OF
# ...

# %%
idx300 = pro.index_daily(ts_code='000300.SH')
idx500 = pro.index_daily(ts_code='000905.SH')
idx1000 = pro.index_daily(ts_code='000852.SH')

# %%
idx1000.head()
# Out:
#      ts_code trade_date      close       open       high        low  \
# 0  000852.SH   20220805  7090.0027  6975.8897  7096.4347  6961.6460
# 1  000852.SH   20220804  6960.3118  6953.9832  6977.3924  6853.6962
# 2  000852.SH   20220803  6916.6704  6968.2919  7079.8536  6893.5238
# 3  000852.SH   20220802  6957.9819  7098.1829  7098.1829  6872.7542
# 4  000852.SH   20220801  7180.4544  7100.7119  7180.4544  7055.6067
#
#    pre_close    change  pct_chg          vol        amount
# 0  6960.3118  129.6909   1.8633  170848496.0  2.398989e+08
# 1  6916.6704   43.6414   0.6310  157896065.0  2.103636e+08
# 2  6957.9819  -41.3115  -0.5937  199046301.0  2.677083e+08
# 3  7180.4544 -222.4725  -3.0983  223088287.0  2.796678e+08
# 4  7117.4341   63.0203   0.8854  162803032.0  2.281600e+08

# %%
funds1000=funds[funds['name'].str.contains('1000')].copy()
funds1000
# Out:
#          ts_code            name management custodian fund_type found_date  \
# 49     015148.OF   华安中证1000指数增强A       华安基金      招商银行       股票型   20220712
# 58     015149.OF   华安中证1000指数增强C       华安基金      招商银行       股票型   20220712
# 116    016033.OF       华宝中证1000C       华宝基金    中国建设银行       股票型   20220701
# 132    015784.OF     中信建投中证1000A     中信建投基金      中信银行       股票型   20220628
# 134    015785.OF     中信建投中证1000C     中信建投基金      中信银行       股票型   20220628
# 617    015466.OF       太平中证1000A       太平基金      交通银行       股票型   20220429
# 619    015467.OF       太平中证1000C       太平基金      交通银行       股票型   20220429
# 634    015495.OF     景顺长城中证1000A     景顺长城基金    中信建投证券       股票型   20220427
# 637    015496.OF     景顺长城中证1000C     景顺长城基金    中信建投证券       股票型   20220427
# 1398   014831.OF   兴银中证1000指数增强A       兴银基金      平安银行       股票型   20220126
# 1399   014832.OF   兴银中证1000指数增强C       兴银基金      平安银行       股票型   20220126
# ...

# %%
for code in funds1000['ts_code']:
    print(code)
    nav = pro.fund_nav(ts_code=code)
    nav.to_pickle('data\%s.pkl'%code, compression='zip')
# Out:
# 015148.OF
# 015149.OF
# 016033.OF
# 015784.OF
# 015785.OF
# 015466.OF
# 015467.OF
# 015495.OF
# 015496.OF
# 014831.OF
# 014832.OF
# 013922.OF
# 013923.OF
# 014202.OF
# 014201.OF
# 014126.OF
# 014125.OF
# 011861.OF
# 011860.OF
# 013442.OF
# 013331.OF
# 006165.OF
# 006166.OF
# 006487.OF
# 006486.OF
# 005313.OF
# 005314.OF
# 004194.OF
# 004195.OF
# 003646.OF
# 003647.OF
# 162413.OF

# %%
funds.to_pickle('data\\funds.pkl')

# %%
funds300.to_pickle('data\\funds300.pkl')
funds500.to_pickle('data\\funds500.pkl')
funds1000.to_pickle('data\\funds1000.pkl')

# %%
idx300.to_pickle('data\\idx300.pkl')
idx500.to_pickle('data\\idx500.pkl')
idx1000.to_pickle('data\\idx1000.pkl')
